# %% [markdown]
# # Web scraping using twitter API
# 어떤 주제와 브랜드에 대해 조사할 때, 사람들이 많이 사용하는 SNS의 언급이나 함께 쓰이는 단어를 통해 해당 브랜드가 어떤 이미지를 가지고 있는지 알 수 있다. 트위터 API를 활용해 특정 검색어에 대한 일반적인 인식을 조사해보자.
#
# - 트위터 선택 이유
#     1. 반응 속도의 신속성 : 트위터는 인스타그램, 페이스북 등 한국에서 쓰이는 SNS 중 가장 반응속도가 빠르다. 즉, 유저들의 실시간 반응을 포장이나 여과 없이 그대로 데이터로 담을 수 있다.
#     2. 텍스트 작성 의도의 정확성 : 트윗당 글자수가 140자(한중일 한정)로 제한되므로 유저들이 자연스럽게 필요한 단어들만 사용하는 자체 필터링을 시도할 수 있다.
#
#     3. 태그 활용 용이 : 유저의 의도를 대신하는 태그 붙임 및 공유가 활성화되어있다. 태그를 통해 텍스트 분석에 이점을 가질 수 있다.
#
# <br>
#
# - 코드 작성 목적
#     1. 특정 검색어 혹은 브랜드에 대한 유저들의 인식 탐색
#     2. 1을 기반으로 wordcloud를 통한 시각화 시도
#     3. 텍스트 데이터의 감성 분석 시도
#
# <br>
#
# 이하의 코드는 [파이썬과 트위터 API를 활용한 트위터 크롤링](http://hleecaster.com/python-twitter-api/)을 참고하여 작성하였다.

# %% [markdown]
# ## 1. 라이브러리 설치

# %%
# !pip install python-twitter
# Out:
# Collecting python-twitter
#   Downloading https://files.pythonhosted.org/packages/b3/a9/2eb36853d8ca49a70482e2332aa5082e09b3180391671101b1612e3aeaf1/python_twitter-3.5-py2.py3-none-any.whl (67kB)
# Requirement already satisfied: requests-oauthlib in c:\users\cucho\anaconda3\lib\site-packages (from python-twitter) (1.3.0)
# Requirement already satisfied: future in c:\users\cucho\anaconda3\lib\site-packages (from python-twitter) (0.17.1)
# Requirement already satisfied: requests in c:\users\cucho\anaconda3\lib\site-packages (from python-twitter) (2.24.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\cucho\anaconda3\lib\site-packages (from requests-oauthlib->python-twitter) (3.1.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\cucho\anaconda3\lib\site-packages (from requests->python-twitter) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\cucho\anaconda3\lib\site-packages (from requests->python-twitter) (1.24.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\cucho\anaconda3\lib\site-packages (from requests->python-twitter) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cucho\anaconda3\lib\site-packages (from requests->python-twitter) (2020.6.20)
# Installing collected packages: python-twitter
# Successfully installed python-twitter-3.5

# %% [markdown]
# ## 2. 라이브러리 불러오기

# %%
# 먼저 트위터 계정을 등록하고 받아놓은 네 개의 key 필요
twitter_consumer_key = ""
twitter_consumer_secret = ""
twitter_access_token = ""
twitter_access_secret = ""

# 라이브러리 불러오기
import twitter

twitter_api = twitter.Api(consumer_key=twitter_consumer_key,
                         consumer_secret=twitter_consumer_secret,
                         access_token_key=twitter_access_token,
                         access_token_secret=twitter_access_secret)

# %% [markdown]
# ## 3. 특정 계정의 타임라인 긁어오기

# %%
account = "@littlelady_bot" # 소녀봇 
statuses = twitter_api.GetUserTimeline(screen_name=account, 
                                       count=1000, # 가져올 수 있는 최대 개수 
                                       include_rts=True, # 리트윗 포함 여부
                                      exclude_replies=False) # 답글 포함 여부
print(statuses)
# Out:
# [Status(ID=1335422065977958400, ScreenName=littlelady_bot, Created=Sun Dec 06 03:13:26 +0000 2020, Text='그저 자정이 다가오는 시간쯤에서 나는 우울을 헤매었고\n당신에게 나는 막다른 길이었음에 울곤 했다.\n\n마른 세수 같은 작별이었다.\n/서덕준, 하고많은 것들 중에 당신을 사랑하였다'), Status(ID=1335406958589878273, ScreenName=littlelady_bot, Created=Sun Dec 06 02:13:24 +0000 2020, Text='타죽어도 좋습니다. 나를 부디 빛으로 이끄십시오.\n/서덕준, 불나방의 자살'), Status(ID=1335391864032137217, ScreenName=littlelady_bot, Created=Sun Dec 06 01:13:25 +0000 2020, Text='막상 네가 나더러 선한 사람이라고 했을 때\n나는 다른 게 되고 싶었어\n이를테면 너를 자랑으로 생각하는 사람\n나로 인해서 너는 누군가의 자랑이 되고\n어느 날 네가 또 슬피 울 때, 네가 기억하기를\n네가 나의 자랑이란 걸\n기억력이 좋은 네가 기억하기를'), Status(ID=1335376765015846912, ScreenName=littlelady_bot, Created=Sun Dec 06 00:13:25 +0000 2020, Text='나는 너한테만 서툴지, 다른 건 다 네가 상상할 수 없을 정도로 교활하고 능숙해. 그건 네가 안 봤으면 좋겠어.\n/오혜원, 밀회'), Status(ID=1335361666104455169, ScreenName=littlelady_bot, Created=Sat Dec 05 23:13:25 +0000 2020, Text='우리는 태어나지 말았어야 했다. 사랑할수록 죄가 되는 날들. 시들 시간도 없이 재가 되는 꽃들. 말하지 않는 말 속에만 꽃이 피어 있었다. 천천히 죽어갈 시간이 필요하다. 천천히 울 수 있는 사각이 필요하다. \n/이제니, 마지막은 왼손으로'), Status(ID=1335225766091472897, ScreenName=littlelady_bot, Created=Sat Dec 05 14:13:24 +0000 2020, Text='당신입니까\n날 경건하게 만들고\n날 착하게 만들고\n미치게 만들고\n/박병희, 당신입니까'), Status(ID=1335210668861968390, ScreenName=littlelady_bot, Created=Sat Dec 05 13:13:25 +0000 2020, Text='네가 오늘은 레즈비언이라고 고백하고 내일은 그것을 부인해도 상관없다. 나는 너에 대해서 가장 잘 말할 수 있는 사람이 너 자신임을 인정한다.\n/김현경 - 사람, 장소, 환대'), Status(ID=1335195566796488713, ScreenName=littlelady_bot, Created=Sat Dec 05 12:13:24 +0000 2020, Text='내가 겁을 먹어도, 고민이 있어도, 신경이 날카로워도 날 사랑해줘요. 내가 잘하지 못해도 있는 모습 그대로 나를 사랑해줘요.\n/알랭 드 보통'), Status(ID=1335180468791078918, ScreenName=littlelady_bot, Created=Sat Dec 05 11:13:24 +0000 2020, Text='그 시절이 지나가기 전에 너를, 단 한번이라도 으스러지게 마주 껴안았어야 했는데.\n그것이 결코 나를 해치지 않았을 텐데.\n나는 끝내 무너지지도, 죽지도 않았을텐데. \n/한강, 희랍어 시간'), Status(ID=1335165365408567297, ScreenName=littlelady_bot, Created=Sat Dec 05 10:13:23 +0000 2020, Text='먼저 사과하는 것이 항상 나의 잘못을 시인하는 것은 아니다. 잘못을 따지는 것보다 우리의 관계가 더욱 소중하다는 뜻이기도 하다.'), Status(ID=1335150278744522755, ScreenName=littlelady_bot, Created=Sat Dec 05 09:13:27 +0000 2020, Text='"한쪽만 골라. 그인지 네 음악인지."\n"골랐어. 그가 내 음악이야."\n/Est Em, Age Called Blue'), Status(ID=1335135166210002944, ScreenName=littlelady_bot, Created=Sat Dec 05 08:13:23 +0000 2020, Text='“좀 기본적인 것부터 시작하자. 이상하지 않니? 나는 네가 내 생명을 구하기 위해 네 생명도 걸 거라는 사실은 알고 있지만…… 네가 제일 좋아하는 색깔이 뭔지는 모른다는 사실이.” /수잔 콜린스, 캣칭파이어'), Status(ID=1335120068514967554, ScreenName=littlelady_bot, Created=Sat Dec 05 07:13:24 +0000 2020, Text='좋아한다 좋아한다 쏟아지는 말을 주워담을 수가 없다 \n/한연희, 수박이 아닌 것들에게'), Status(ID=1335104971415535616, ScreenName=littlelady_bot, Created=Sat Dec 05 06:13:24 +0000 2020, Text='지난 생에 우리는 무엇이었을까.\n죽어 가는 너를 안고 어쩔 줄 몰라하던 골짜기에서 너와 아프게 이별한 적이 있었던 것일까. 너와 나 사이를 건너가고 건너오는 애틋함은 어느 생에서 여기까지 이어져 오는 걸까.\n/도종환, 연분홍'), Status(ID=1335089873909211136, ScreenName=littlelady_bot, Created=Sat Dec 05 05:13:25 +0000 2020, Text='그만해 친구 같은 건 안 해\n네가 옆에 있으면\n너를 안고 싶고 너를 갖고 싶어\n난 그러니까 더 이상 장난치지 마 \n아무 때나 손잡지 마\n곁에 오지 마\n두근거리게 만들지 마\n/스탠딩 에그, 뭘까'), Status(ID=1335074769713053697, ScreenName=littlelady_bot, Created=Sat Dec 05 04:13:24 +0000 2020, Text='사랑하는 사람을 만들지 말고\n미워하는 사람도 만들지 말라\n사랑하는 사람은 못 만나 괴롭고\n미워하는 사람은 만나 괴롭다.\n/법구경'), Status(ID=1335059674828132352, ScreenName=littlelady_bot, Created=Sat Dec 05 03:13:25 +0000 2020, Text='"계속 곁에 있을게요."\n"거짓말쟁이."\n"거짓말이 아니에요. 하지만...... 거짓말이어도 상관없잖아요."\n/이와이 슌지, 립반윙클의 신부'), Status(ID=1335044569486950402, ScreenName=littlelady_bot, Created=Sat Dec 05 02:13:23 +0000 2020, Text='같은 고통도 사람에 따라 견뎌낼 수 있는 정도가 다르고, 어떤 고통은 개인이 도저히 극복해낼 수 없어. 그 때 우리가 서로의 약한 순간을 위해 손 잡아주지 않는다면, 우리는 누구나, 언젠가 약할 수밖에 없는… https://t.co/n1zPWAwrR6'), Status(ID=1335029474874703872, ScreenName=littlelady_bot, Created=Sat Dec 05 01:13:25 +0000 2020, Text='그래, 꽃을 던지렴 \n\n웃는 얼굴로\n아프게 맞아줄게\n\n꽃으로 멍들어\n더 이상 질투하지 않게\n더 이상 미워하지 않게\n\n그래, 꽃을 던지렴\n웃는 얼굴로\n향기에 취해\n그 사람 다시 그리워하게\n/최반 - 그래, 꽃을 던지렴'), Status(ID=1335014373308317697, ScreenName=littlelady_bot, Created=Sat Dec 05 00:13:24 +0000 2020, Text='나는 사랑하고 사랑받았던 시간만을 기억하고자 애썼다. 나는 그를 꽃으로 기억한다.  ...

# %% [markdown]
# ### 텍스트만 추출하기

# %%
for status in statuses:
    print(status.text) # 텍스트가 깨질 경우 : print(status.text.encode('utf-8'))
    print()
# Out:
# 그저 자정이 다가오는 시간쯤에서 나는 우울을 헤매었고
# 당신에게 나는 막다른 길이었음에 울곤 했다.
#
# 마른 세수 같은 작별이었다.
# /서덕준, 하고많은 것들 중에 당신을 사랑하였다
#
# 타죽어도 좋습니다. 나를 부디 빛으로 이끄십시오.
# /서덕준, 불나방의 자살
#
# 막상 네가 나더러 선한 사람이라고 했을 때
# 나는 다른 게 되고 싶었어
# 이를테면 너를 자랑으로 생각하는 사람
# 나로 인해서 너는 누군가의 자랑이 되고
# 어느 날 네가 또 슬피 울 때, 네가 기억하기를
# 네가 나의 자랑이란 걸
# 기억력이 좋은 네가 기억하기를
#
# 나는 너한테만 서툴지, 다른 건 다 네가 상상할 수 없을 정도로 교활하고 능숙해. 그건 네가 안 봤으면 좋겠어.
# /오혜원, 밀회
#
# 우리는 태어나지 말았어야 했다. 사랑할수록 죄가 되는 날들. 시들 시간도 없이 재가 되는 꽃들. 말하지 않는 말 속에만 꽃이 피어 있었다. 천천히 죽어갈 시간이 필요하다. 천천히 울 수 있는 사각이 필요하다.
# /이제니, 마지막은 왼손으로
#
# 당신입니까
# 날 경건하게 만들고
# 날 착하게 만들고
# 미치게 만들고
# /박병희, 당신입니까
#
# 네가 오늘은 레즈비언이라고 고백하고 내일은 그것을 부인해도 상관없다. 나는 너에 대해서 가장 잘 말할 수 있는 사람이 너 자신임을 인정한다.
# /김현경 - 사람, 장소, 환대
#
# 내가 겁을 먹어도, 고민이 있어도, 신경이 날카로워도 날 사랑해줘요. 내가 잘하지 못해도 있는 모습 그대로 나를 사랑해줘요.
# /알랭 드 보통
#
# 그 시절이 지나가기 전에 너를, 단 한번이라도 으스러지게 마주 껴안았어야 했는데.
# 그것이 결코 나를 해치지 않았을 텐데.
# 나는 끝내 무너지지도, 죽지도 않았을텐데.
# /한강, 희랍어 시간
#
# 먼저 사과하는 것이 항상 나의 잘못을 시인하는 것은 아니다. 잘못을 따지는 것보다 우리의 관계가 더욱 소중하다는 뜻이기도 하다.
#
# "한쪽만 골라. 그인지 네 음악인지."
# "골랐어. 그가 내 음악이야."
# /Est Em, Age Called Blue
#
# “좀 기본적인 것부터 시작하자. 이상하지 않니? 나는 네가 내 생명을 구하기 위해 네 생명도 걸 거라는 사실은 알고 있지만…… 네가 제일 좋아하는 색깔이 뭔지는 모른다는 사실이.” /수잔 콜린스, 캣칭파이어
#
# 좋아한다 좋아한다 쏟아지는 말을 주워담을 수가 없다
# /한연희, 수박이 아닌 것들에게
#
# 지난 생에 우리는 무엇이었을까.
# 죽어 가는 너를 안고 어쩔 줄 몰라하던 골짜기에서 너와 아프게 이별한 적이 있었던 것일까. 너와 나 사이를 건너가고 건너오는 애틋함은 어느 생에서 여기까지 이어져 오는 걸까.
# /도종환, 연분홍
#
# 그만해 친구 같은 건 안 해
# 네가 옆에 있으면
# 너를 안고 싶고 너를 갖고 싶어
# 난 그러니까 더 이상 장난치지 마
# 아무 때나 손잡지 마
# 곁에 오지 마
# 두근거리게 만들지 마
# /스탠딩 에그, 뭘까
#
# 사랑하는 사람을 만들지 말고
# 미워하는 사람도 만들지 말라
# 사랑하는 사람은 못 만나 괴롭고
# 미워하는 사람은 만나 괴롭다.
# /법구경
#
# "계속 곁에 있을게요."
# "거짓말쟁이."
# "거짓말이 아니에요. 하지만...... 거짓말이어도 상관없잖아요."
# /이와이 슌지, 립반윙클의 신부
#
# 같은 고통도 사람에 따라 견뎌낼 수 있는 정도가 다르고, 어떤 고통은 개인이 도저히 극복해낼 수 없어. 그 때 우리가 서로의 약한 순간을 위해 손 잡아주지 않는다면, 우리는 누구나, 언젠가 약할 수밖에 없는… https://t.co/n1zPWAwrR6
#
# 그래, 꽃을 던지렴
#
# 웃는 얼굴로
# 아프게 맞아줄게
#
# 꽃으로 멍들어
# 더 이상 질투하지 않게
# 더 이상 미워하지 않게
#
# 그래, 꽃을 던지렴
# 웃는 얼굴로
# 향기에 취해
# 그 사람 다시 그리워하게
# /최반 - 그래, 꽃을 던지렴
#
# 나는 사랑하고 사랑받았던 시간만을 기억하고자 애썼다. 나는 그를 꽃으로 기억한다. 그래서 나의 상처는 아름답다.
# /박청호, 사랑의 수사학
#
# 그리하여 사랑이여, 차라리 죽는다면 당신 손에 죽겠다.
# /안현미, 사랑의 사계
#
# 안녕, 나는 가야만 해 내일 또 만날 수 있게
#
# 사랑이란 생각의 분량이다
# /허형만, 사랑론
#
# 이제는 당신의 저만치 가 있는 마음도 좋아요
# /허수경, 수박
#
# 이렇게 될 줄 알면서도
# 당신이 무작정 좋았읍니다.
# /조병화, 이렇게 될 줄을 알면서도
#
# 금요일 밤에도 나에게 소홀하지 말아줘.
#
# "삶은 아름다운 거라고
# 꼭 말해 주고 싶어요"
# 라고 말하며
# 꽃이 죽는다
# /자크 프레베르, 3월의 태양
#
# 다시 너를 사랑하지 않을 수 있게
# 꽃을 보려거든, 이름 없이 태어나라
# 봄 한 시절에 피는
# 저게 무슨 꽃인지 나는
# 그해 여름이 되어서야 알게 되었다
# /함성호, 이름이 없으면 장미의 향기도 사라지리라
#
# 나라는 먼지는 너라는 별을 구성하는 중요한 진실이다.
# /김선우, 나들의 시, 너의 무덤가에서
#
# 사람들이 경멸에 찬 눈으로 보거나 욕을 하고 지나갈 때마다 나는 생각합니다. 당신은 평생 이 정도로 사랑하는 감정을 알지 못할 거야, 라구요.
# /이희주, 환상통
#
# 아, 껴안고 싶은 밤이다
# /홍영철, 홍초가 보고 싶어
#
# 눈에 밟힌다는 건 마음을 찌른다는 것
# /이은규, 속눈썹의 효능
#
# 한 사람이 다른 한 사람을 향해 할 수 있는 가장 간절한 말, '나도 너를 사랑해'라는 말의 속뜻은 바로 이것이다. '나는 결여다'
# /신형철, 정확한 사랑의 실험
#
# "네 목소리가 정말 괜찮은 것 같아서 걱정이구나."
# /이현미, 시간의 끝
#
# 네 곁에서 걷는 게 싫어
# 한 번씩 너의 손이 스치잖아
# 그 때마다 잡고 싶은데
# 하지만 난 그러면 안 되잖아
# /스탠딩 에그, 고백
#
# 당신을 저주했었습니다 하지만 오늘 밤 목련이 죽음처럼 떨어져나갈 때 당신을 그리워합니다
# /허연, 목련이 죽는 밤
#
# 패션이 발달하기 시작한 것은 "여자는 남자에게 잘 보이기 위해 자신을 꾸민다" 라는 원시적 명제를 버리고 나서부터다.
# /박병우, 1cm
#
# 이루지 못한 사랑에는 화려한 비탄이라도 있지만
# 이루어진 사랑은 이렇게 남루한 일상을 남길 뿐인가
# /은희경, 빈처
#
# "삶은 아름다운 거라고
# 꼭 말해 주고 싶어요"
# 라고 말하며
# 꽃이 죽는다
# /자크 프레베르, 3월의 태양
#
# 무엇을 사랑하건 그 사랑의 깊이가
# 대상을 잃었을 때 슬픔의 깊이를 결정한다.
# /제인 구달, 희망의 이유
#
# 나는 네가 보는 것을 보았다
# 네가 사랑하는 것을 증오하기 위해
# /여성민, 세 번의 방
#
# 사랑한다고, 사랑받고 싶다고 말을 못해
# 무슨 병에라도 옮아서는
# 곧 떨어져버릴 듯이 매달려 있고 싶다
# /이향, 사과
#
# 한 사람이 떠났는데
# 서울이 텅 비었다
# /문정희, 기억
#
# 저 고칠 수 없는 질병을 우리는 사랑이라 부른다
# /이경교, 꽃노을
#
# 사람은 사람을 서로 아프게 하여
# 스스로 낫기도 하겠다는데
# 나는 한사코 혼자 앓겠다는 사람 옆에 있다
# /이병률, 자상한 시간
#
# 네가 그림 그리는 걸 좋아하고 화를 낼 줄 아는 사람이어서, 나는 꽃무더기 속에서 꽃으로 태어난다.
# /이성미, 거짓말
#
# 이젠 빼앗기지 마. 네 시간은 네 거야.
# /정유정, 내 심장을 쏴라
#
# 다정히 사랑해 주세요.
# /박상수, 슈가 마블
#
# 나는 조금도 울지 않을 거다. 나는 그 사람을 결코 사랑하지 않았습니다. 처음부터 추호도 사랑하지 않았습니다.
# /다자이 오사무, 유다의 고백
#
# 그날, 텔레비전 앞에서 늦은 저녁을 먹다가
# 울컥 울음이 터졌다
# 멈출 수 없어 그냥 두었다
# 오랫동안 오늘 이전과 이후만 있을 것 같아
# 밤새 잠을 이루지 못했다
# /곽효환, 그날
#
# 나 이제 어디서 널 그리워하지
# /김형영, 수평선
#
# 눈이 부셔요, 단지 바라보았을 뿐인데요
# /강서완, 밀밭 소나타
#
# 죽을 게 아니면 살아야 했다. 살 것이면 제대로 살아야 했다.
# /김이설, 환영
#
# 그대 때문에 사는데
# 그대를 떠나라 한다
# /도종환, 희망
#
# 누군가가 한 사람을 지극히 사랑할 때, 그러나 그 사람을 이미 잃었을 때, 대부분의 모든 사람들은 한 개인이 세상보다도 소중하다는 주장을 갖게 되기 마련이지.
# /전민희, 세월의 돌
#
# 넌 내 세상을 바꿀 거야
# 네 등 뒤로 감춘 꽃다발 하나면 아마 충분할 것 같은 걸
# /가을방학, 나비가 앉은 자리
#
# 아니요. 아무도 강하지 않아요. 누구에게라도 그렇게 말해선 안되는것 같아요.
# /이상우, 프리즘
#
# 있잖아, 잘 있어?
# 네 웃음에 나는 부레를 잃은 인어처럼 숨이 막혀
# /장이지, 명왕성에서 온 이메일
#
# 왜 우리한테 다른 사람이 필요해?
# 꼭 그렇게 말하는 것 같았다.
# 우리에겐 서로가 있는데.
# /레이먼드 카버, 대성당
#
# "오늘도 어떻다고?"
# "사랑하죠, 오늘도."
# /김금희, 너무 한낮의 연애
#
# 당신은 비를 사랑한다 말했지만 우산을 폈습니다.
# 당신은 햇살을 사랑한다 말했지만 그늘진 곳을 찾았습니다.
# 당신은 바람을 사랑한다 말했지만 창문을 닫았습니다.
# 이것이 내가 당신이 내게도 사랑한다 말할까 두려운 이유입니다.
# /I Am Afraid
#
# 평범한 감정을 고백이라고
# 할 수는 없지 않은가.
# 고백이란,
# 말로 하는 것이 아니라
# 일생으로 하는 것이다.
# /용윤선, 울기 좋은 방
#
# 기다리지 않겠다
# 원하지 않겠다
# 그리워하지 않겠다
# 마음을 꾹꾹 눌러 밟으며,
# 겨울의 한기에서 벗어나려고 뒷걸음 친다
# /조진국, 사랑하지만 사랑하지않는다
#
# 아, 저 발자국
# 저렇게 푹푹 파이는 발자국을 남기며
# 나를 지나간 사람이 있었지
# /도종환, 발자국
#
# 사랑하는 사람과 헤어지는 일이란 한 번 자살하는 것과 같다 익숙했던 모든 것들과 생이별하는 것이다 저승을 두려워하는 것은 그곳의 모든 것이 내가 사랑하던 것이 아니기 때문이다
# /김경주, 비정성시
#
# 사람들의 포옹은 슬프다. 가장 가까이 있지만. 그 순간부터 서로의 얼굴을 볼 수 없다. 가장 가까운 이별이다.
# /이영도, 눈물을 마시는 새
#
# 난 너에게 내가 원하는 걸 한 번도 말하지 않았으니까
# 언제나 언제나 나에게는 네가 원하는 것이 내가 원하는 것보다 중요했으니까
# 너는 나를 사랑하지 않고 나는 너를 사랑하므로 내가 원하는 걸 네가 모르는 것은 너무나 당연한 일이지
# /모두에게 해피엔딩
#
# 어느 한쪽이 창 밖에 서 있어야 한다면
# 그 사람은 나였으면
# 당신은 그저 다정한 불빛 안에서
# 행복해라
# 따뜻해라
# /황경신, 거리
#
# 그러고 보니
# 우리 사이 참 아무 것도 아니었다
# /임경림, 생일 그 다음 날
#
# 누군가를 좋아하면 시간은 둘로 나뉜다.
# 함께 있는 시간과
# 그리고 함께 있었던 시간을 떠올리는 시간.
# /은희경, 소년을 위로해줘
#
# 널 만난 후로 나에게
# 사계절 같은 건 없었어
#
# 내 속에 네가 들어와
# 뜨거운 꽃을 심었던
# 옅은 봄
#
# 그리고 그것이 만개해
# 꽃잎이 온몸을 타고 흐르던
# 찐한 봄
#
# 내겐 어쨌든 봄뿐이었어
# 널 만난 후로 나에겐
# /박치성, 널 만난 후 봄
#
# 힘이 들면 당연히 힘을 못내는 거잖아. 힘들면 힘내지 마세요. 그래도 돼요.
# /심준모, 어떤 하루
#
# 언젠가 우주가 다시 태어나도 쏟아지는 별들 속에서도
# 다시 또 너를 찾아내 완벽한 그 순간에 네게 인사 할게
# /랄라스윗, 완벽한 순간
#
# 언젠가 날 울렸던 아름다운 모습으로
# 오늘 밤 꿈속에 다시 나를 찾아와
# /짙은, 고래
#
# 너는 내 통증의 처음과 끝.
# 너는 비극의 동의어이며 너와 나는 끝내 만날 리 없는여름과 겨울.
# 내가 다 없어지면 그때 너는 예쁘게 피어.
# /서덕준, 상사화 꽃말
#
# 사랑하는 사람아
# 이렇게 첫머리를 쓰고 목이 메어 울었다
# /최돈선, 바다엽신
#
# 찰나였지만 그 찰나가 존재했었다는 기억으로 어떤 사람들의 관계는 지탱될 때가 있다.
# /용윤선, 울기 좋은 방
#
# 내가 나로 사는 것이 왜 누군가에겐 상처일까요?
# /김정연, 혼자를 기르는 법
#
# 바라보면
# 꽃이었고
#
# 돌아서면
# 그리움이었다
#
# 나는
# 왜
# 그 짓을
# 못했을까, 꺾어들면
# 시든 다음에도
# 나의 꽃인 것을
#
# /정규화, 꽃을 위한 헌시
#
# 향나무는 자기를 찍는 도끼 날에도 향을 묻힌다.
#
# 이렇듯 흐린 날에 누가
# 문 앞에 와서
# 내 이름을 불러 주면 좋겠다
#
# 보고 싶다고
# 꽃나무 아래라고
# 술 마시다가
# 목소리 보내오면 좋겠다
#
# 난리난 듯 온 천지가 꽃이라도
# 아직은 내가 더 이쁘다고
# 거짓말도 해주면 좋겠다
# /구양숙, 봄날은 간다
#
# 누가 더 잔인한 지 내기하기
# 그게 사랑이었다
# /김명남, 먼발치의 안쪽
#
# 정말로 죽을 것처럼 힘이 들 때, 가장 힘을 주는 말은 '힘 내'보다 '나도 그래'라는 공감이었다.
# /한설, 스물아홉 늦었다고 하기엔 미안한
#
# "갖고 싶은 게 있어요."
# "뭐죠?"
# "꽃 한 송이만."
# "가지세요, 두 송이, 스무 송이, 좋으실 대로요."
# "아니, 한 송이면 됩니다. 하지만 당신이 따서 내게 주세요."
# /샬롯 브론테, 교수
#
# 그녀에게 고백했다
#
# "내가 너를 사랑한다면 어쩌겠니"
#
# 오, 어리석었던
# 가정법 고백
# /박상천, 가정법 고백
#
# "그런데 왜 나같은 걸 사랑하는거니?"
# "왜냐고? 어린아이에게 왜 태어났느냐고 물어봐. 꽃에게 왜 피었느냐고 물어보라고. 태양에게 왜 비추느냐고 물어봐.
# 나는 그대를 사랑하지 않을 수 없기 때문에 사랑하고 있는 거야."
# /막스 뮐러, 독일인의 사랑
#
# 안녕, 나는 가야만 해 내일 또 만날 수 있게
#
# "제가 졌어요. 그를 사랑했던 것이 최초의 실수였고....... 그게 결국 저를 쓰러뜨렸던 거예요."
# /기형도, 겨울의 끝
#
# 이토록 격렬하고
# 이토록 연약하고
# 이토록 부드럽고
# 이토록 절망하는 이 사랑
#
# 다른 이들을 두렵게 하고
# 다른 이들을 말하게 하고
# 다른 이들을 질리게 하던
# 이 사랑
# /자크 프레베르, 이 사랑
#
# 우주 저편에서 너의 별이 되어줄게.
# /배명훈, 청혼
#
# 누가 그렇게
# 하염없이 어여뻐도 된답니까.
# /서덕준, 능소화
#
# "서울에 연애하러 가냐?"
# "연애도 할 거 아냐."
# "하겠지."
# "좋겠다."
# "너도 하든가."
# "너 없어서 안 할 거다."
# 걸음을 멈췄다.
#
# /김이설, 비밀들
#
# 밤이면
# 향기에 미친 별들이 쏟아져 내리도록
# 그리운 얼굴만큼
# 하늘 창을 열어 놓아야지
#
# 별에 찔려
# 백혈이 낭자한 밤을 사르다
#
# 아침이면
# 연보라 꽃물 든 시집에 얼굴을 묻고
# 처참하게 죽어 있어야지
# /강효수, 라일락 블라썸
#
# 관계의 모순 중 하나는
# 우리가 사랑한다고 주장한 이들보다도
# 좋아하지도 않는 사람들에게
# 훨씬 더 잘해주게 된다는 사실이다.
# /알랭 드 보통, 사랑의 기초
#
# 죽고 싶을 때가 있었다
# 너와 함께 죽고 싶을 때가 있었다
# 왜 그러는지
# 영문도 모르면서
#
# 태어난 순간부터
# 너는 내 것이 아니었는데
# 너를 동반할 어떤 권리도
# 나에게는 없었는데
# 나는 불행하지도 않았는데
# /다니카와 슌타로, 아버지는
#
# 꼬마들은 어른들이 모른다고 생각하지.
# 하지만 그렇지 않아.
# 어른들은 싫증이 난 거지.
# /보노보노
#
# 사람이 사람을 귀찮아하면 안 된다. 결국 귀찮아하는 사람을 그리워하게 되므로. 사람이 사람을 고마워하면 안 된다. 결국 고마워하는 사람을 사랑하게 되므로.
# /용윤선, 울기 좋은 방
#
# 기억해. 네가 믿는다면 그건 거짓말이 아니야.
# /조지 코스탄자, 사인펠드
#
# 어떤 사람이 나를 안 좋아하는 것 같으면 그 사람을 겁내게 돼. 나에 대한 무슨 권력같은 게 그 사람한테 생기는 거야.
# /은희경, 소년을 위로해줘
#
# 우는 구나
# 펑펑울고 마는구나
#
# 기어이 울고 말것을
# 왜 한나절이나 참았니
#
# 견딘다는 건 그렇게
# 울음을 참는게 아니란다
# /최옥, 그리고 비
#
# 너는 오늘도 여전히 기다리고 있구나.
# 내가 죽었다는 것을 아직도 모르는지.
# /우치다 린타로, 너무 울지 말아라
#
# 무엇보다
#
# 그 무엇보다
# 꼭 죽이고 싶던 사람
#
# 그가 먼저 세상을 떠났다
# /김경미, 슬픔이 해준 것들
#
# 나는 가끔 궁금해지네
# 그대는 몇살까지 아름다울까
# /심보선, 무화과 꿈
#
# 월요일 아침에도 사랑해줘.
#
# 당신이 툭, 깨뜨리기 전에 난 이미 깨질 만큼 깨졌다.
# /이민하, 개랑 프라이
#
# 이 남아도는 나를 어찌해야 할까
# 더 이상 너의 시간 속에 살지 않게 된 나를
# /나희덕,  잉여의 시간
#
# 함께 갈까요? 하는 듯이 당신이 내 눈을 오랫동안 들여다보았을 때
# 함께 갈 수 없는 길이잖아요 라는 듯이 나는 눈을 피했다.
# /김충규, 뭐였나 서로에게 우리는
#
# 여름 끝자락에 내린 소낙비는
# 너도
# 나도 젖게 만들었다
#
# 너는 옷이 젖고
# 나는 마음이 젖었다
# /유진, 소낙비
#
# 너를 처음 본 순간 예감했지.
# 나는 이제부터 너로 인해 울게 되겠구나.
# /이미나, 아이 러브 유
#
# 꾸준히 글을 쓰기 위해서는 항상 잘 쓰기만 하겠다는 생각은 버려라. 꾸준히 쓰면서 늘 잘 쓸 수는 없다.
# /제니퍼 이건
#
# 당연히 나는 당신을 아프게 하겠지.
# 당연히 당신도 나를 아프게 할 테고.
# /생테쥐페리, 나탈리 팔레에게 보낸 편지
#
# 이상한 일이다
#
# 너는 분명 하나의 빛도, 잉크도 아니었는데
# 내게 번짐을 알려주었다 그 뜻을 깨우쳐 주었다
#
# 이내 네가 내 안 가득 번지고
# 나는 막을 겨를이 없다
# /백가희, 번지다
#
# Love people. Use things. Not vice-versa.
# 사람을 사랑하고, 사물을 이용하라. 반대로 하지 마라.
#
# 어른이 되는 과정은 분명 징검다리를 건너는 것이라 생각했지만 몇 단계의 징검다리를 건넜어도 나의 의식은 여전히 특정 시기에 머물러 있고, 어느 날 갑자기 주변의 정황과 시간들은 미처 준비도 하지 못한 나에게 느닷없이 어른이 되라며 등을 떠미는 것이다.
#
# 하찮은 원고란 없다. 네가 하찮게 쓸 뿐이지.
# /나가토모 켄지, 바텐더
#
# 달력을 넘기다 손이 찢어졌어요
# 어머니가 웃으시면서 손을 붕대로 감싸주었어요
# 얘야, 시간은 날카롭단다
# /순간을 읊조리다
#
# 달을 보지 말걸
# 너에게 말 걸지 말걸
# 그때 웃지 말걸......
# /박시하, 창문
#
# 그는 상처투성이였다. 그는 상처투성이였다. 상처를 보면 상처를 본 사람이 놀란다. 상처입은 사람은 벌써 상처를 잊어버린 것처럼 보인다. 하지만 잊을 순 없을 거야. 잊을 순 없을 거야.
# /보노보노
#
# 왜 네 빛은 나만 비추지 않는 거야 왜 나만 사랑하지 않는 거야
# 왜 외간 것들에게도 웃어주는 거야 왜 따뜻한 거야 왜 모두에게 다정한 거야
# /김선우, 해괴한 달밤
#
# 너는 무슨 색깔로 또 다른 사랑을 꿈꾸었을까
# /기형도, 밤눈
#
# 편견은 내가 다른 사람을 사랑하지 못하게 하고
# 오만은 다른 사람이 나를 사랑하지 못하게 한다.
# /오만과 편견
#
# 내게는 사랑이란 첫 독서가
# 당신이란 책이었고 행복했고 열렬했어요
# 어느 페이지는 다 외워버렸고,
# 어느 페이지는 찢어 없앴고,
# 어느 페이지는 슬퍼서
# 두 번 다시 들여다보고 싶지 않았지만
# 어쨌든 즐거웠습니다
# /박연준, 소란
#
# "키스는 말이 더 이상 필요하지 않을 때 말하는 것을 막는 자연에 의해 고안된 사랑스러운 술수다."
# /잉그리드 버그먼
#
# 내가 꺾으려 하자
# 꽃이 가냘프게 말했네
# 절 시들도록 굳이
# 꺾어야겠어요?
# /괴테, 발견
#
# 나는 너를 경멸해. 널 참아주는 나를 경멸하듯이.
# /프랑수아즈 사강, 길모퉁이 카페
#
# 오만 뒤에는 공포가 숨어 있다. 괴로운 열등감에 시달리는 사람만이 남에게 당신은 나를 상대할 만한 인물이 못 된다는 느낌을 심어주려고 기를 쓴다.
# /알랭 드 보통, 불안
#
# 나는 벗어날 수가 없다.
# 그녀는 지구 위에서 가장 완벽한 중력이다.
# /김민준, 계절에서 기다릴게
#
# 잊어버리는 건 쉽지만
# 다시 떠오르는 건 막을 수가 없다.
# /허연, 시정잡배의 사랑
#
# 사랑이여.
#
# 나는 그대의 하얀 손발에 박힌
# 못을 빼주고 싶다.
# 그러나
#
# 못박힌 사람은 못박힌 사람에게로
# 갈 수가 없다.
# /김승희, 시계풀의 편지 4
#
# 잊어버려야 하겠다는 말은
# 잊을 수 없다는 말입니다
# 정말 잊고 싶을 때는 말이 없습니다
# /한용운, 인연설
#
# 그대만을 하염없이 기다렸는데
# 그대 말을 철석같이 믿었었는데
# 찬 바람에 길은 얼어붙고
# 나도 새하얗게 얼어버렸네
#
# 내겐 잘못이 없다고 했잖아
# 나는 좋은 사람이라 했잖아
# 상처까지 안아준다 했잖아
# 거짓말 거짓말
# /이적, 거짓말 거짓말 거짓말
#
# 나는 깊이깊이 추락해야해
# 발바닥부터 서서히 꺼져들어가며, 참으로
# 연극적으로 죽어가는게 실은 나의 사랑인 까닭에
# /최승자, 20년후에 志에게
#
# 막막하다.
# 그럴 때면 나는 벽에 바짝 모로 붙어 그의 기울어진 어깨를 감싸 쥐고 살며시 그 울음소리를 껴안곤 했다.
# /김 산, 하현
#
# 나 죽도록
# 너를 사랑했건만,
# 죽지 않았네
#
# 내 사랑 고만큼
# 모자랐던 것이다
# /박철, 사랑
#
# 이마에 난 흉터를 묻자 넌
# 지붕에 올라갔다가
# 별에 부딪친 상처라고 했다
#
# 누가 그걸 옛 수첩에다 적어 놓은 걸까
# 그 지붕 위의
# 별들처럼
# 어떤 것이 그리울수록 그리운 만큼
# 거리를 갖고 그냥 바라봐야 한다는 걸
# /류시화, 첫사랑
#
# 저 꽃은 지면서
# 이 적막을 견뎌보라 하네
# 나 혼자 견뎌보라고 하네
# /김용택, 이 적막한 저 꽃 향기
#
# 안녕, 나는 가야만 해 내일 또 만날 수 있게
#
# 사이먼턴에 따르면, 궁극적으로 성공을 일궈내는 사람과 실패하는 사람을 가르는 기준은 그저 얼마나 시도를 많이 했느냐, 그리고 기꺼이 실패를 계속할 의지가 있느냐, 이것뿐이다.
# /알렉스 리커만, 지지 않는 마음
#
# 사람 그리워 당신을 품에 안았더니
# 당신의 심장은 나의 오른쪽 가슴에서 뛰고
# 끝내 심장을 포갤 수 없는
# 우리 선천성 그리움이여
# /함민복, 선천성 그리움
#
# 많은 상처를 주었고 적은 상처를 받았다 이 불균형 덕분에 지금까지 살아왔고 앞으로도 살아 갈 것이다
# /신형철, 몰락의 에티카
#
# 금요일 밤에도 나에게 소홀하지 말아줘.
#
# 잘 지내주어요
# 더이상 내가 그대 안의 분홍빛 아니어도
# 그대의 봄 아름답기를
# /강인호, 봄안부
#
# 네가 내 살 속에 내가 네 꽃잎 속에
# 서로 붉게 몸을 섞었다는 이유만으로
# 열에 열 손가락 핏물이 들어
# 네가 만지고 간 가슴마다
# 열에 열 손가락 핏물 자국이 박혀
# 사랑아 너는 이리 오래 지워지지 않는 것이냐
# /도종환, 봉숭아
#
# 너를 만나서 행복했고
# 너를 만나서 오래 고통스러웠다
# /도종환, 자목련
#
# 사람은 내 것이 아니지만 기억은 내 것이기에
# 그 시절이 소중할 뿐이다.
# /용윤선, 울기 좋은 방
#
# 한번도 본 적 없는 이를 문장으로 문장으로 스치다가도 눈물이 나 그가 아니면 안되겠다 하였다
# 사랑하였다
# 무의미였다
# /이병률, 고양이 감정의 쓸모
#
# 완전한 아름다움이란 곧 파괴될 어떤 것이다. 어느 날의 너처럼.
# /이광호, 지나치게 산문적인 거리
#
# "오늘은 너를 빌려가고 싶어. 가지고 싶다는 말은 하지 않을게."
# /김선우, 다만, 오골계 백숙 먹기
#
# 나는 젖어가는 꿈속이다
# 나쁜 일처럼 당신들에게 번지기 시작한다
# /김지녀, 나쁜 일
#
# 연애라는 게임에서 이기기위해 감정을 아꼈던 승자들은 깨닫게 될 것이다. 사랑은 승자와 약자로 나뉘는 게임이 아니라 마음을 비우고 떠나는 사람과 후회하며 남겨진 사람으로 나뉘는 게임이라는 것을. 그래서 사랑에선 더 많이 사랑하는 쪽이 유리하다.
#
# 오래 보고 싶었다
# 오래 만나지 못했다
# 잘 있노라니
# 그것만 고마웠다
# /나태주, 안부
#
# (이사하던 날도 그대의 편지를 버리지 못했음)
#
# /허연, 저녁 가슴 한쪽
#
# 슬퍼서가 아니라,
# 그저 여러가지 일들로 울고싶어했다는 기분이 들었다.
# /요시모토 바나나, 키친
#
# 다음엔 불빛으로 태어나고 싶다는
# 술집 창가에 비친 널 똑바로 볼 수 없어 나는 눈을 도려내고 말았지
# 그토록 아름다운 것 앞에서는 어떤 표정을 지어야 하나
# /이현호, 금수의 왕
#
# 그대는 떠날 때도 아름다워야 해요.
#
# 슬픈 추억은 발바닥에 꽂힌 가시 같은 겁니다. 가장 좋은 방법은 그 가시를 빼서 어깨 너머로 집어던지고 끝까지 걸어가는 것입니다. 하지만 대부분 그 가시마저도 사랑하기에 뽑지 못합니다. 레이디 케이트 데솔로, 행복하시길 바랍니다.
# /이영도, 퓨처워커
#
# 꽃아, 나를 줄까?
#
# /정영, 화대
#
# 언젠가 우리가 도달해야 할 곳에 울음이 잘 익은 열매로 와서 시커멓게 썩고 있다
# /이향, 모과
#
# 나는 내가 보고 싶은
# 그대 모습을 보았네
# 그것이 결코
# 그대가 아님을 알지 못한 채
#
# 나는 널 사랑했었나
# 나는 날 사랑했었나
# 이게 다 뭔 소용인가
# 결국 다 하는 헛소리
#
# 우리는 서로를 속이며 살아가는 사람
# 우리는 서로를 속이며 사랑하는 사람
#
# 나는 네가
# 그런 어둡고 탁한 깊이를 평생 모르고 살아가길 바란다
# /최금진, 잠수함
#
# 하루 종일 너를 생각하지 않고도 해가 졌다
# 너를 까맣게 잊고도
# 꽃은 피고 이렇게 날이 저물었구나
#
# 네가 잊혀진다는 게 하도 이상하여
# 내 기억 속에 네가 희미해진다는 게 이렇게 신기하여
# 노을 아래서 꽃가지를 잡고 놀란다
# /김용택, 젖은 옷은 마르고
#
# 아픈데는 없냐고 당신이 물었다
# 없다, 라고 말하는 순간
# 말과 말 사이의 삶들이 아프기 시작했다
# 물소리가 사무치게 끼어들었다
# /이병률, 눈 사람 여관
#
# 오직 죽은 물고기들만 물결을 따라 헤엄친다.
#
# 사랑은
# 늘 곁에 있었지만
# 나는 그에게
# 날개를 달아주지 못했다
#
# 쳐다보면 숨이 막히는
# 어쩌지 못하는 순간처럼
# 그렇게 눈부시게 보내버리고
#
# 그리고
# 오래오래 그리워했다
# /문정희, 순간
#
# 이별은
# 별이 되는 것
#
# 이 한 칸 띄우고 별
# 한 칸, 그래
# 한 걸음 멀어졌을 뿐이다
#
# 그 별도 아니고
# 저 별도 아니고
#
# 내 가장 가까운 곳에서
# 빛나는 별
#
# 너는 나의
# 별이 되었을 뿐이다
# /이장근, 이별
#
# 네가 나의 눈을 태양이라고 불러준 이후로 나는 그늘에서 나왔지
# /이제니, 블랭크 하치
#
# 많이 보고 싶겠지만
# 조금만 참자.
# /나태주, 묘비명
#
# 다 괜찮다
# 다만 뭘 해도 행복하기를
#
# 절벽 끝에서라도
# 스스로에게 상처주지 말기를
# /정이현, 풍선
#
# 살면서
# 중요하다고 생각해왔던 것들이
# 실제로는 대단치도 않았다
# 그것들을 내려놓고서도
# 나는 끄덕없이 달렸다
# 반면 내가 대단치않게 여겼던것들이
# 실제로는 중요했다
# 예를 들자면
# 나 자신
# /심윤경, 사랑이 달리다
#
# 너의 음성은 차갑고
# 너의 표정은 싸늘하지만
# 너를 볼 때마다 화상을 입는다
# /박건호, 섭씨 100도의 얼음
#
# 너는 매혹적이다 사랑스럽다 언제 어디서나 눈길을 끈다 애초에 그렇게 태어났다
# /오은, 커버스토리
#
# 네가 나의 애인이라면
# 너는 참 좋을 텐데
# /진은영, 시인의 사랑
#
# 내가 먼저 빠졌다
# 만만하게 봤는데
# 목숨보다 깊었다
#
# 어차피 수영금지구역이었다
# 어설프게 손 내밀다
# 그도 빠진건
# 누구의 탓도 아니었다
#
# 우리는 익사할 것이다
#
# 바닥에 즐비한
# 다른 연인들처럼
# 하지만 누가 뭐라해도
# 내가 먼저 빠졌다
# /전윤호, 물귀신
#
# 미국 스미스소니언박물관에서 천 년 후 열어볼
# 타임캡슐을 제작했다
#
# 다양한 목소리가 미래를 향해 던져졌다
# 그중에서도 노숙자 맥 그레인이 던진 한마디는 이거였다
#
# 얘들아, 너희도 사랑을 하니
# 너희도 누군가가 그립고 마음이 아프니
# /박철, 정말
#
# 날 구해줘 너를 멈출 수가 없어
# 내 온몸을 휘감는 엉킨 매듭이 모두 너였어
# /김연우, 해독제
#
# 이토록 평화로운 지옥에서 한 무명 시인이 왕이었던 시절
# 세상은 한 권의 책이고 그 책엔 네 이름만이 적혀 있었을 때
# /이현호, 13월의 예감
#
# 너를 예로 들어
# 남을 위로할때가 올까봐
# 나도 그런적이 있다고
# 담담하게 말하게 될까봐
# /원태연, 두려워
#
# 마음의 어디를 동여맨 채 살아가는 이를
# 사랑한 것이 무섭다고 너는 말했다
#
# 사랑할 수 있는 사람들 틈에서 마음껏
# 사랑하며 살아가는 일
#
# 아무것도 원하지 않으나 다만
# 보호받으며 살아가는
# 그런 눈부신 일이 차례가 올 리 없다고 너는 말했다
# /조정권, 목숨
#
# 잊지 못하는 여자가 있다고 굳이 말로 하는 남자는, 비겁한 부류이다.
# /전경린, 천사는 여기 머문다
#
# 너무 멀리까지는 가지 말아라
# 사랑아
#
# 모습 보이는 곳까지만
# 목소리 들리는 곳까지만 가거라
#
# 돌아오는 길 잊을까 걱정이다
# 사랑아.
# /나태주, 부탁
#
# 여우는 50살이 되면 부인으로 변할 수 있고 백 살이 되면 미인이나 남자로 변할 수 있다. 천 살이 된 여우는 하늘과 통하게 되어 천호天狐가 된다. 이 중 상급의 신에 필적할 만한 능력을 가진 여우를 특별히 호조사狐祖師라 한다.
# /현중기玄中記
#
# 그 아이를 개로 만들고 싶어서 나는 쓰기 시작했다 쓰다 보니 그것은 소설이었다 아름답고 아름다운 소설이었다
#
# 그 아이가 나를 사랑한다고 말하지 않았다
# 자꾸 짖었다
#
# 나는 나의 아름다운 소설을 보여주고 싶었으나 그 아이는 개가 아니다
# /황인찬, 오수
#
# 사람은 많은데 그 사람은 없다
#
# /길상호, 터미널에서 낚시질
#
# 내가 밤일 때 그는 낮이었다
# 그가 낮일 때 나는 캄캄한 밤이었다
#
# 그것이 우리 죄의 전부였지
#
# 나의 아침이 너의 밤을 용서못하고
# 너의 밤이 나의 오후를 참지 못하고
#
# 안녕이란 말도 없이 우리는 헤어졌다
# /최영미, 사랑의 시차
#
# 한참이나 말이 없던 내가
# 처음 던진 질문은
# 왜 봄에 죽으려 했냐는 것이었다
#
# 창밖을 바라보던 당신이
# 내게 고개를 돌려
# 그럼 겨울에 죽을 것이냐며 웃었다
#
# 마음만으로는 될 수도 없고
# 꼭 내 마음 같지도 않은 일들이
# 봄에는 널려 있었다
# /박준, 그해 봄에
#
# 그대가 내 왼팔을 깨물었어
# 물어뜯었어도 별로 상관없었는데,
# 지금도 붉게 보라색 흔적이 남아서
# 이게 사라질때까지가 나의 수명같다는 기분이 들었지
# /Radwimps, Scissors stand
#
# 가끔 내가 쓰는 모든 시들이 유서 같다가 그것들이 모두 연서임을 깨닫는 새벽이 도착한다
# /안현미, 불면의 뒤란
#
# 내 나머지 삶이
# 그대의 삶보다 한참 더 남았어도
# 나는 지금
# 그대의 종말과 나의 죽음을 바꾸고 싶다
# 후회 없겠다
# 행복하겠다
#
# 내 눈물에 침몰하는 내가 싫다
#
# 보고 싶다
# 살고 싶다
# /강효수, 그녀에게
#
# 바보가 되어간다는 얘기지.
# 너에게 가까이 가고 싶은 마음 그 외에는 모두 공허하니까, 네가 전화를 걸어주거나 네가 나에게 와 주거나 그것 밖에는 중요한 일이 없으니까.
# /신경숙, 깊은 슬픔
#
# 그대 사랑하는 동안
# 내게 우는 날이 많았었다
#
# 사랑하던 그 사람
# 조금만 더 다가서면
# 서로 꽃이 되었을 이름
# /문정희, 찔레
#
# 전화벨이 울렸다 수화기를 들었다 말이 없었다
# 잠시 그렇게 있다 전화가 끊겼다
#
# 한 발짝을
# 더 나아가지 못하고 넘어서지 못하고
# 그냥 돌아선 그는 누구였을까
#
# 나도 그러했었다
# 가까이 가려다 그만 돌아선 날이 있었다
# /도종환, 끊긴 전화
#
# "가장 힘든 건 바다 맨 밑에 있을 때야."
# "왜요?"
# "다시 올라가야 할 이유가 생각나지 않거든."
# "우린 같은 문제를 안고 있네요."
# "왜지?"
# "당신 곁에 남을 이유를 찾는 것이 너무 어렵거든요."
# /그랑 블루
#
# 이 남아도는 나를 어찌해야 할까
# 더 이상 너의 시간 속에 살지 않게 된 나를
# /나희덕, 잉여의 시간
#
# 지금 무슨 생각을 하고 있는지도 난 알고 있다.
# 그녀는 바지보다는 치마를 좋아하며 연분홍을 좋아한다.
# 그리고 반가운 사람의 이름을 두 번 부른다는 것도 난 알고 있다.
# …그녀가 날 사랑하지 않는다는 것도 알고 있다.
# /김종완, 난 많은 것을 알고 있다
#
# 우리는
# 서로가 기억하던 그 사람인 척하기 위해
# 애를 쓰고 있다
# /김소연, 사랑과 희망의 거리
#
# 아이한테 물었다
# 이담에 나 죽으면
# 찾아와 울어줄 거지?
# 대답 대신 아이는
# 눈물 고인 두 눈을 보여주었다
# /나태주, 꽃그늘
#
# 헤어질 때, 더 다정한 쪽이 덜 사랑한 사람이다.
# /마르셀 프루스트
#
# "나는 쇄골이 반듯한 사람이 좋습니다."
# "그렇군요."
# "좋아합니다."
# "쇄골을요?"
# "은교씨를요."
# "......나는 쇄골이 하나도 반듯하지 않은데요."
# "반듯하지 않아도 좋으니까 좋은 거지요."
# "그렇게 되나요."
# /황정은, 백의 그림자
#
# 사랑은 너를
# 영원히 믿을 수 있는
# 종교로 만들었고
#
# 이별은 너를
# 영원히 만날 수 없는
# 신으로 만들었다
#
# /김병훈, 아름다운 너를 잊을 수 있을까
#
# 몽골에서는 기르던 개가 죽으면 꼬리를 자르고 묻어준단다
# 다음 생에서는 사람으로 태어나라고,
#
# 사람으로 태어난 나는 궁금하다
# 내 꼬리를 잘라 준 주인은 어떤 기도와 함께 나를 묻었을까
# 가만히 꼬리뼈를 만져본다
# /이운진, 슬픈 환생

# %%
output_file_name = "twitter_get_timeline_result.txt"

with open(output_file_name, "w", encoding="utf-8") as output_file:
    for status in statuses:
        print(status, file=output_file)

# %% [markdown]
# ## 4. 검색하기

# %% [markdown]
# ### 검색어 지정

# %%
query = "롯데리아"
statues = twitter_api.GetSearch(term=query, count=200)

for status in statues:
    print(status.text)
    print()
# Out:
# 롯데리아 박우진 당첨 브로마이드도 있어요!
#
# 롯데리아에서 버거+손소독제 세트판다ㄷㄷ
#
# 와이씨 근데 롯데리아 언니들 다들 이쁘다...
#
# 맥딜리버리 시킬까 롯데리아 갈까 고민중임
#
# RT @dead_assistant: 깨달았다
# 취업하려고 대학가는건
# 양념감자 먹으려고 롯데리아 가는거랑 같구나
# 메인메뉴는 햄버거지만
# 그닥 엄청나게 맛있지도 않고,
# 아무도 그거에 대해 신경안씀
# 버거학회 사람들만 신경쓰지..
#
# 음ㅁ 다이어트 중인데 롯데리아옴 걍 망한듯 ㅋㅋㅎㅋㅎㅋ
#
# 하..보일러않틀고자서나지금콧물이주룩주룩나 코읍나는 아니겟지???ㅠ 나 코세글자걸리먼 롯데리아문닫아야대 이디야도 문닫앗던데
#
# 이제 오전시험 끝나서 롯데리아로 밥먹으러 왔어요(˃̣̣̣̣︿˂̣̣̣̣ )
# 아이고 힘들어.... https://t.co/p8Lbgp6TW1
#
# 수제버거먹고싶은데
# 롯데리아에 비슷한거없겟지
# 내가어무많은걸 바라는거갯지
#
# 나 롯데리아 왔오
#
# @kookooyujiny 롯데리아 알바생 소환하고 시픈데 참으께여👀.ㆍ
#
# RT @foodnjoy: 롯데리아가 식물성패티 신메뉴 출시. 미라클버거 말고 연초 일부 지점에서 시험판매했던 버거로 네슬레의 스위트어스 콩단백 패티를 사용. 16일부터 판매 예정 (세트 5200원 기프티콘 선판매 https://t.co/nB0EvxX…
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# RT @Tvxq_info_2: shinhangroup_official ig 이벤트
# #유노윤호 #정윤호 #U_Know #ユンホ
# ⠀
# 📌참여방법
# ① 신한금융그룹 인스타그램 팔로우
# ② 댓글로 초성퀴즈의 정답 입력
#
# 📌선물
# - 유노윤호 명언티셔츠 5종 세트…
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# 🐭 트위터 닉네임 추천해드림
# ──────────────────
# 샨의 새 닉네임 : 롯데리아 케찹도둑
# https://t.co/xzWSUoKjRY
#
# ㅇ ㅏ 니
#
# ㅇ
# ㅗ  ㅐ애
#
# 나도 옙흔 닉넴 조오오 ㅠㅠㅠㅠ
#
# RT @ryunan_9903: 스위트 어스 어썸 버거(롯데리아)
# 단품 5,600원/세트 7,400원
# https://t.co/NxgJmwW0PK
#
# 롯데리아의 식물성 패티 햄버거 2탄. 일반 패티에 비해 약 2~3배 정도 두꺼운 대체육을 사용한 햄버거.…
#
# 스위트 어스 어썸 버거(롯데리아)
# 단품 5,600원/세트 7,400원
# https://t.co/NxgJmwW0PK
#
# 롯데리아의 식물성 패티 햄버거 2탄. 일반 패티에 비해 약 2~3배 정도 두꺼운 대체육을 사… https://t.co/rhSt0IhopJ
#
# RT @psychokinesis23: 오늘 롯데리아 손님 바글바글했습니다...
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# @PdSPiCa 음......커피라고 해서 당연히 커피숍인 줄 알았는데 롯데리아일줄은.....
#
# @ishidai_kage 롯데리아요
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @abc_ChocoLove: #lobotomy_corporation
# #로보토미_코퍼레이션
# 로보토미 로고가 롯데리아랑 비슷하단 트윗을 봐서,,,, https://t.co/KDlo7mjQ10
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# @Foot_Garak_ 드밧두랑 롯데리아가서 햄버거 먹고 방송국간거 그리그 얁즍이랑 놀이공원간거  근대 다 입덕하고 몇일 안 도ㅑ서 꾼 꿈잉ㅁ
#
# @0818Allme 롯데리아ㅏㅏ
#
# 아까 롯데리아 먹었음.
#
# 롯데리아에서 치킨을 먹었다고?? (흠칫)
#
# @seinMeister142 ㅇㅈ 낼 엄마 몰래 롯데리아 먹어야지 ㅋㅋㅋㅋ
#
# 콘칩 이랑 롯데리아 데리버거 사먹기 양념감자도
#
# 졍오졔 전학생 윤이랑 짝 되자마자 맨날 윤한테 구라침 우리 등교할때 트랙터 타고간다 밥에 맨날 감자반찬만 먹는다 롯데리아가 뭔지 모른다 우리는 소때려잡아서 버거 만들어먹는다 ㅇㅈㄹ하는데 윤에게 1도 안통함… https://t.co/Kl9gykVuEt
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# 근데 영국은 맥도날드도 역겨움
# 버거킹에서 와퍼 시켜봣는데
# 롯데리아가 훨씬 푸짐함 ㅆㅂ새끼들
#
# 롯데리아는 무슨 이점이 있어서 가격이 저럴까..?? 이번에 나온 스위트 어썸 버거도 세트가 8500원인데 그렇다고 버거가 큰 것도 아니고 감튀가 맛있는 것도 아니고. 차라리 롯데리아에서 창렬스러운 버거 먹을… https://t.co/uViUPE1qtg
#
# 에버랜드 피자먹고싶다고 말해야하는데 롯데리아 피자먹고싶다고 말했어 장난하냐고...... 진짜 엥망진창
#
# 첨에 롯데리아 알림소리인줄알았어 https://t.co/xVaXipT94X
#
# @school_kook 헉 개수님 저 궁금한 게 있는데요 혹시 양념감자 좋아하세요? 좋아하시면 무슨 맛 좋아하세요? 감튀에 캡쳡 얼마나 찍어 드세요? 캡찹 몇봉지 뜯으세요? 맥날이 좋으세요 롯데리아가 좋으세요 맘터가 좋으세요 버거킹이 좋으세요?
#
# 배진영 진영 굿즈 양도
#
# 공식 포카 (일괄시 덤⭕️
# 증명사진 증사
# 포카 바인더
#
# 썸머패키지 포토북 외
# 롯데리아 스페셜기프트 포카
# 부메랑 포카
#
# dm
#
# #배진영 #BAEJINYOUNG #jinyoung… https://t.co/VJyCJ5Jw4V
#
# @pastaoop 와개쩐다네맞습니다이제부터춘향이는장발이아니라숏컷입니다너가그린춘향이가너무맛있어서이제춘향이내손으로못그릴것같음나같은후레오너보다는너가춘향오너하는게춘향이도좋아할듯춘향이절대숏컷해요즘누가장발하냐진짜맛알못… https://t.co/8lhoPBfgFJ
#
# RT @chirhyeung: 롯데리아에서 해볼것 https://t.co/P0zmt3dHAe
#
# RT @8888777887787D: 롯데리아는 빅맥~ 맥도날드는 피자가 짱~ https://t.co/X8DM1G6ZCm
#
# 당케 먼저 먹고 모지라면 롯데리아를 조지겠습니다 저는 강한 여자
# 넷플 보면서 당케 조져야지 https://t.co/eiLzXsFuyJ
#
# @Yun_seou_rain ㅈ데리아지만 우리들의 마음속 햄버거 근본임 ㄷㄷ
# 사실 새벽에는 롯데리아밖에 배달 안해
#
# 오늘 아무것도 안먹어서 당딸려서 머리아픈가해서
# 대충먹었는데
# 좀이따가 배고프면 롯데리아 ㄱ다
#
# 롯데리아 미라클버거 리뷰중에 웃긴게 감튀는 비건인데 맛도있다고
#
# 💫
#
# 아침 : 닭곰탕
# 점심 : 롯데리아 버거
# 저녁 : 짜장면
# 그 외 식사(카페인섭취유무) : ×/야식: 회 치즈랍스타
# 충분한 수분 섭취여부: 적당히
# 수면시간 : 7시간
# 일기: 오늘 야식 휘황찬란 자자잔 오… https://t.co/ZQ2suLIDY9
#
# @Gaemi3_3 혹시 롯데리아에서 스테이크 먹엇니? 도라이구나
#
# 저녁으로 냉장고에 투썸 당케 있는거 퍼먹을까
# 아님 롯데리아 버거 시킬까?
#
# RT @dead_assistant: 깨달았다
# 취업하려고 대학가는건
# 양념감자 먹으려고 롯데리아 가는거랑 같구나
# 메인메뉴는 햄버거지만
# 그닥 엄청나게 맛있지도 않고,
# 아무도 그거에 대해 신경안씀
# 버거학회 사람들만 신경쓰지..
#
# @heeme_S2 나 오늘 롯데리아에서 2만원 씀 미친년이
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# 김재환 팬콘 폴라 포카 양도 지마켓 인생네컷 포토 에세이 인화사진 이니스프리 팝업스토어 아이더 엽서 중국폴라 중국 대만 프로필카드 플카 스티커 ipu 굿즈 md 엠디 렌티큘러 담요 썸머키트 썸머 원더월드 원… https://t.co/AAyPIQ1qKZ
#
# 내가 일하는곳이 사거리에 있는데 건너편에 진짜 거짓말 하나도 안하고 맥도날드 롯데리아 맘스터치 KFC 다 있음 진짜 거짓말 안하고 그래서...너무 힘들어...
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# @XX0326XXMM 아아주 많은 에피소드가 있죠..... 아침에 롯데리아에서 만나기 전부터 얘기하자
#
# @9to6_ 동네에 롯데리아가읍네이요
#
# @pastaoop 넌 롯데리아 버거를 사랑한게아니라 내가 롯데리아 소프트콘을 사랑하는 것처럼 롯데리아 포테이토를 사랑한거구나ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅇㅋㅇㅋ이해했음
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# @wngdor6 나오늘 롯데리아햄버거 먹었는데
#
# @pastaoop 뭐야 나 맨날 맘터가서 싸이버거만 먹는다고 머라했음서 너도 롯데리아가서 버거 두종류 밖에 안 먹은거임.????🤬🤬
#
# 7. 바게트에 롯데리아 녹차 토네이도 얹어 먹는 거 좋아해요 학교 다닐 때는 주변에 빵집과 롯데리아가 둘 다 있었는데 지금은 둘 다 없어서 눈물 훔침ㅠ
#
# @pastaoop ㅋㅋㅋㅋㅋㅋㅌㅋㅋㅋㅋㅋㅋㅋ그럼 롯데리아 젤 맛있는 버거가 뭐임?? 기회되면 나중에 먹어볼께
#
# @pastaoop ㅋㅋㅋㅋㅋㅋ밀리터맄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 아 그건 왜빼는데ㅡㅡ 너가 사랑하는 롯데리아면 밀리터리도 품어줘야하는거 아니야??ㅡㅡ
#
# @pastaoop ㅠㅠ햄버거는 맘터가 짱임
# 난 롯데리아가면 소프트콘 말고 안 사먹음.. 소프트콘 맛있는건 인정 햄버거는 노인정
#
# RT @psychokinesis23: 오늘 롯데리아 손님 바글바글했습니다...
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# 근데 되게 오랫동안 롯데리아였던 자리라 뭐가 들어올지 모르겠다.
#
# RT @sysaseyo: 훈승 다투면ㅎ 박성휸 이히승알바하는롯데리아에 혼자 앉아서 하루종일 감자튀김 처먹고잇음
# 이히승 프로사회인이라 비가시화오지게하고 알바에전념하다 마감시간 다돼서 '손님 저희매장 영업끝났습니다..' 하면 박성휸 '저는아직배고픈데요'
#
# 롯데리아 찾아봤는데... 10시까지만 영업한다네... https://t.co/d5laiJmZ95
#
# 저거 롯데리아 왕관아닌가 https://t.co/Y8PygKPXoh
#
# @WKN_CRE 이... 산동네에는 KFC는 고사하고 롯데리아조차 없습니다.....
#
# 고3 이 남자요 버거킹이나 롯데리아에서 햄버거 산거 sns에 올리네요 애는 아싸는 아닌거죠? 쫌 잘 노는 앤가요?https://t.co/sz9zqdrKEr
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# @ghettonoa @hytei117 연어튀김만여ㅎㅎ.
# 흰살생선튀김은 괜찬항ㅇㅎ!!  롯데리아 새우버거 뫄이썽!!!
#
# 옹성우 모여라워너블 1.5
# 옹성우 캐리어포카 0.7
# 👆2개 일괄시 2.0
#
# 배진영 스트랩포카 0.5
# 팬콘 dvd 멤별 0.1
# 롯리 응모권 0.1
#
# 준미포가격, 3천원이상부터 거래
# 일괄시 에눌
#
# 비공굿 덤👌… https://t.co/9yqClIKTx1
#
# @1EaI8mQeBuxWm0E ㅇㄴ 롯데리아ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 그러게요 저희 거기 가서 치즈스틱 다 거덜내고 왔잖아요^^
# ㅇㄴ
# 소매넣기는 NO!! 당신의 돈을 애껴.
# 자꾸 그러시면 제이콥 더 착즙하고 아주 어어?
# 그럴거에요.
#
# RT @psychokinesis23: 오늘 롯데리아 손님 바글바글했습니다...
#
# 아 롯데리아인가 아 모르갯어요 죄송합니다
#
# RT @N0RD_LYS: 이거 학교 롯데리아 안에 있던 안내문인데 존나 나폴리탄 괴담같음...
# 롯데리아 버거가 맛있다고 말하는 손님을 목격할 시, 최대한 빨리 그 자리를 벗어나 직원에게 알려주십시오. https://t.co/KkRdPB3kJI
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @GB__S2__GB: @fearocket 아악 그럼 약간 저만의 팁을 드리자면..
#
# 얇은 감튀-맥날, 롯데리아
# 두꺼운 감튀-버거킹, 케엪씨
# 시즈닝 감튀-맘스터치, 롯데리아 양념감자
#
# 이렇게 시켜드셔보세여..
# 저는 갠적으론 저기서 종류가 다르게…
#
# @fearocket 아악 그럼 약간 저만의 팁을 드리자면..
#
# 얇은 감튀-맥날, 롯데리아
# 두꺼운 감튀-버거킹, 케엪씨
# 시즈닝 감튀-맘스터치, 롯데리아 양념감자
#
# 이렇게 시켜드셔보세여..
# 저는 갠적으론 저기서… https://t.co/KjsejVnURx
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @karmentheotaku_: 누가 로보토미 보고 롯데리아래ㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠㅠㅠ https://t.co/s1stpu5sak
#
# RT @psychokinesis23: 오늘 롯데리아 손님 바글바글했습니다...
#
# RT @humwhoru: 롯데리아 코퍼레이션
#
# 패티에 직면하고
# 햄버거를 창조하라 https://t.co/u7Y3xevDgz
#
# RT @psychokinesis23: 오늘 롯데리아 손님 바글바글했습니다...

# %% [markdown]
# ### 해시태그로 검색

# %%
query = "#롯데리아"
statuses = twitter_api.GetSearch(term=query, count=200)

for status in statuses:
    for tag in status.hashtags:
        print(tag.text)
        print()
# Out:
# 롯데리아
#
# 퀵오더
#
# 롯데리아배달
#
# 롯데리아주문
#
# sell
#
# 워너원
#
# 워너원굿즈양도
#
# 윤지성
#
# 하성운
#
# 김재환
#
# 옹성우
#
# 황민현
#
# parkjihoon
#
# sell
#
# 워너원
#
# 워너원굿즈양도
#
# 윤지성
#
# 하성운
#
# 롯데리아
#
# 퀵오더
#
# 롯데리아배달
#
# 롯데리아주문
#
# 스위트어스어썸버거
#
# 롯데리아
#
# 비건버거
#
# 스위트어스
#
# 콩고기
#
# 비건
#
# 강다니엘
#
# 굿즈
#
# 이니스프리
#
# 씽크네이처
#
# 봄바람
#
# 에너제틱
#
# 투비원
#
# 지마켓
#
# 랩
#
# 인스타일
#
# 플레시아
#
# 롯데리아
#
# 하이트
#
# 롯데마트
#
# 롯데리아
#
# 롯데백화점
#
# 롯데시네마
#
# 롯데제과
#
# 롯데아쿠아리움
#
# 롯데아울렛
#
# 롯데캐슬
#
# 강다니엘
#
# 굿즈
#
# 이니스프리
#
# 씽크네이처
#
# 봄바람
#
# 에너제틱
#
# 투비원
#
# 지마켓
#
# 랩
#
# 인스타일
#
# 플레시아
#
# 롯데리아
#
# 하이트
#
# 황민현
#
# 민현

# %%
# 빈도수 높은 순으로 정렬
from collections import Counter

query = "#롯데리아"
statuses = twitter_api.GetSearch(term=query, count=200)

result=[]

for status in statuses:
    for tag in status.hashtags:
        result.append(tag.text)
        
Counter(result).most_common(15)
# Out:
# [('롯데리아', 6),
#  ('퀵오더', 2),
#  ('롯데리아배달', 2),
#  ('롯데리아주문', 2),
#  ('sell', 2),
#  ('워너원', 2),
#  ('워너원굿즈양도', 2),
#  ('윤지성', 2),
#  ('하성운', 2),
#  ('황민현', 2),
#  ('강다니엘', 2),
#  ('굿즈', 2),
#  ('이니스프리', 2),
#  ('씽크네이처', 2),
#  ('봄바람', 2)]

# %% [markdown]
# ## 5. 스트리밍으로 데이터 수집하기

# %%
import json

query = ["롯데리아"]
output_file_name = "stream_result.txt"

with open(output_file_name, "w", encoding='utf-8') as output_file:
    stream = twitter_api.GetStreamFilter(track=query)
    
    while True:
        for tweets in stream:
            tweet = json.dumps(tweets, ensure_ascii=False)
            print(tweet, file=output_file, flush=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-2a6a27bffb0c> in <module>
#       8
#       9     while True:
# ---> 10         for tweets in stream:
#      11             tweet = json.dumps(tweets, ensure_ascii=False)
#      12             print(tweet, file=output_file, flush=True)
#
# ~\Anaconda3\lib\site-packages\twitter\api.py in GetStreamFilter(self, follow, track, locations, languages, delimited, stall_warnings, filter_level)
#    4591
#    4592         resp = self._RequestStream(url, 'POST', data=data)
# -> 4593         for line in resp.iter_lines():
#    4594             if line:
#    4595                 data = self._ParseAndCheckTwitter(line.decode('utf-8'))
#
# ~\Anaconda3\lib\site-packages\requests\models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     793         pending = None
#     794
# --> 795         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     796
#     797             if pending is not None:
#
# ~\Anaconda3\lib\site-packages\requests\models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     488         """
#     489         if self.chunked and self.supports_chunked_reads():
# --> 490             for line in self.read_chunked(amt, decode_content=decode_content):
#     491                 yield line
#     492         else:
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     664
#     665             while True:
# --> 666                 self._update_chunk_length()
#     667                 if self.chunk_left == 0:
#     668                     break
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     596         if self.chunk_left is not None:
#     597             return
# --> 598         line = self._fp.fp.readline()
#     599         line = line.split(b';', 1)[0]
#     600         try:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
